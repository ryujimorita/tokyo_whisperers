# %%
# Install Whisper
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-wdrm5moc
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-wdrm5moc
#   Resolved https://github.com/openai/whisper.git to commit 90db0de1896c23cbfaf0c58bc2d30665f709f170
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20240930) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20240930) (1.26.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20240930) (2.5.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20240930) (4.66.6)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20240930) (10.5.0)
# Collecting tiktoken (from openai-whisper==20240930)
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting triton>=2.0.0 (from openai-whisper==20240930)
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton>=2.0.0->openai-whisper==20240930) (3.16.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20240930) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20240930) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20240930) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20240930) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20240930) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20240930) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20240930) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20240930) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->openai-whisper==20240930) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper==20240930) (3.0.2)
# Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 4.1 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.3 MB/s eta 0:00:00
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20240930-py3-none-any.whl size=803583 sha256=363b910a8bd8232ad7c31cf26a671bfaddadba3e971fb9ff7b1fcb5eea7eb4b3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sdsyey5e/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# Installing collected packages: triton, tiktoken, openai-whisper
# Successfully installed openai-whisper-20240930 tiktoken-0.8.0 triton-3.1.0

# %%
# Install system dependencies (libsndfile1 and ffmpeg)
# !apt-get install -y libsndfile1 ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.31-2ubuntu0.1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# Clone the ReazonSpeech repository
# !git clone https://github.com/reazon-research/reazonspeech
# Out:
# Cloning into 'reazonspeech'...
# remote: Enumerating objects: 371, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 371 (delta 95), reused 81 (delta 73), pack-reused 246 (from 1)
# Receiving objects: 100% (371/371), 78.43 KiB | 2.80 MiB/s, done.
# Resolving deltas: 100% (217/217), done.

# %%
# Install ReazonSpeech Nemo
# !pip install --no-warn-conflicts reazonspeech/pkg/nemo-asr

# Install ReazonSpeech K2
# !pip install --no-warn-conflicts reazonspeech/pkg/k2-asr

# Install ReazonSpeech ESPnet
# !pip install --no-warn-conflicts reazonspeech/pkg/espnet-asr
# Out:
# Processing ./reazonspeech/pkg/nemo-asr
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from reazonspeech-nemo-asr==2.1.0) (1.26.4)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from reazonspeech-nemo-asr==2.1.0) (0.10.2.post1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from reazonspeech-nemo-asr==2.1.0) (0.12.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from reazonspeech-nemo-asr==2.1.0) (2.5.1+cu121)
# Requirement already satisfied: nemo_toolkit[asr] in /usr/local/lib/python3.10/dist-packages (from reazonspeech-nemo-asr==2.1.0) (2.0.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-nemo-asr==2.1.0) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-nemo-asr==2.1.0) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-nemo-asr==2.1.0) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-nemo-asr==2.1.0) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-nemo-asr==2.1.0) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-nemo-asr==2.1.0) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-nemo-asr==2.1.0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-nemo-asr==2.1.0) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-nemo-asr==2.1.0) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-nemo-asr==2.1.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-nemo-asr==2.1.0) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->reazonspeech-nemo-asr==2.1.0) (1.17.1)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.26.3)
# Requirement already satisfied: onnx>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.17.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.8.2)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.18.6)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (75.1.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.17.1)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.3)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (4.66.6)
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.17.0)
# Requirement already satisfied: braceexpand in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.1.7)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.8.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.8.0)
# Requirement already satisfied: g2p-en in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.1.0)
# Requirement already satisfied: jiwer in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.0.5)
# Requirement already satisfied: kaldi-python-io in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.2.2)
# Requirement already satisfied: kaldiio in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.18.0)
# Requirement already satisfied: lhotse>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.28.0)
# Requirement already satisfied: marshmallow in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.23.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (24.2)
# Requirement already satisfied: pyannote.core in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (5.0.0)
# Requirement already satisfied: pyannote.metrics in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.2.1)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.25.1)
# Requirement already satisfied: pyloudnorm in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.1.1)
# Requirement already satisfied: resampy in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.4.3)
# Requirement already satisfied: sox in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.5.0)
# Requirement already satisfied: texterrors in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.5.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.1.0)
# Requirement already satisfied: fiddle in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.3.0)
# Requirement already satisfied: hydra-core<=1.3.2,>1.3 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.3.2)
# Requirement already satisfied: omegaconf<=2.3 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.3.0)
# Requirement already satisfied: pytorch-lightning>2.2.1 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.4.0)
# Requirement already satisfied: torchmetrics>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.6.0)
# Requirement already satisfied: transformers>=4.44.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (4.46.3)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.18.7)
# Requirement already satisfied: webdataset>=0.2.86 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.2.100)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.1.0)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (7.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.2.2)
# Requirement already satisfied: sacremoses>=0.0.43 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.1.1)
# Requirement already satisfied: sentencepiece<1.0.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->reazonspeech-nemo-asr==2.1.0) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->reazonspeech-nemo-asr==2.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->reazonspeech-nemo-asr==2.1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->reazonspeech-nemo-asr==2.1.0) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->reazonspeech-nemo-asr==2.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->reazonspeech-nemo-asr==2.1.0) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->reazonspeech-nemo-asr==2.1.0) (2.22)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.32.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core<=1.3.2,>1.3->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (4.9.3)
# Requirement already satisfied: click>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from lhotse>=1.26.0->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (8.1.7)
# Requirement already satisfied: cytoolz>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from lhotse>=1.26.0->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.0.0)
# Requirement already satisfied: intervaltree>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from lhotse>=1.26.0->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.1.0)
# Requirement already satisfied: tabulate>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from lhotse>=1.26.0->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.9.0)
# Requirement already satisfied: lilcom>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from lhotse>=1.26.0->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.8.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa->reazonspeech-nemo-asr==2.1.0) (0.43.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.7.0->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (4.25.5)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa->reazonspeech-nemo-asr==2.1.0) (4.3.6)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>2.2.1->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.11.9)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacremoses>=0.0.43->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2024.9.11)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa->reazonspeech-nemo-asr==2.1.0) (3.5.0)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.44.0->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.44.0->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.4.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.11.9)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from fiddle->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.4.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from fiddle->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.20.3)
# Requirement already satisfied: libcst in /usr/local/lib/python3.10/dist-packages (from fiddle->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.5.1)
# Requirement already satisfied: nltk>=3.2.4 in /usr/local/lib/python3.10/dist-packages (from g2p-en->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.9.1)
# Requirement already satisfied: distance>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from g2p-en->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.1.3)
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.10/dist-packages (from inflect->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from inflect->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (4.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->reazonspeech-nemo-asr==2.1.0) (3.0.2)
# Requirement already satisfied: rapidfuzz<4,>=3 in /usr/local/lib/python3.10/dist-packages (from jiwer->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.10.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.16.0)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.core->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.4.0)
# Requirement already satisfied: pyannote.database>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (5.1.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.6.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.8.0)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from pyloudnorm->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.0.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.2.12)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.1.3)
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.10/dist-packages (from texterrors->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.13.6)
# Requirement already satisfied: plac in /usr/local/lib/python3.10/dist-packages (from texterrors->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.4.3)
# Requirement already satisfied: loguru in /usr/local/lib/python3.10/dist-packages (from texterrors->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.7.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from texterrors->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.5.0)
# Requirement already satisfied: Levenshtein in /usr/local/lib/python3.10/dist-packages (from texterrors->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.26.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.1.43)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (5.9.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.19.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.3.4)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from cytoolz>=0.10.1->lhotse>=1.26.0->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.12.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.2.0)
# Requirement already satisfied: typer>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (5.0.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]->reazonspeech-nemo-asr==2.1.0) (0.1.2)
# Building wheels for collected packages: reazonspeech-nemo-asr
#   Building wheel for reazonspeech-nemo-asr (pyproject.toml) ... done
#   Created wheel for reazonspeech-nemo-asr: filename=reazonspeech_nemo_asr-2.1.0-py3-none-any.whl size=7773 sha256=8f26c91100f9ab9b205e97632b4dc19c9e7a7d9d59851930476869c7ce3c5256
#   Stored in directory: /root/.cache/pip/wheels/ed/41/96/c0922ee0ed0ce5a298f4ec49b78095d5f334fd41f7133b5e56
# Successfully built reazonspeech-nemo-asr
# Installing collected packages: reazonspeech-nemo-asr
#   Attempting uninstall: reazonspeech-nemo-asr
#     Found existing installation: reazonspeech-nemo-asr 2.1.0
#     Uninstalling reazonspeech-nemo-asr-2.1.0:
#       Successfully uninstalled reazonspeech-nemo-asr-2.1.0
# Successfully installed reazonspeech-nemo-asr-2.1.0
# Processing ./reazonspeech/pkg/k2-asr
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from reazonspeech-k2-asr==2.1.0) (1.26.4)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from reazonspeech-k2-asr==2.1.0) (0.10.2.post1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from reazonspeech-k2-asr==2.1.0) (0.12.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from reazonspeech-k2-asr==2.1.0) (0.26.3)
# Collecting sherpa-onnx (from reazonspeech-k2-asr==2.1.0)
#   Downloading sherpa_onnx-1.10.33-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (32 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->reazonspeech-k2-asr==2.1.0) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->reazonspeech-k2-asr==2.1.0) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->reazonspeech-k2-asr==2.1.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->reazonspeech-k2-asr==2.1.0) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->reazonspeech-k2-asr==2.1.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->reazonspeech-k2-asr==2.1.0) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->reazonspeech-k2-asr==2.1.0) (4.12.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-k2-asr==2.1.0) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-k2-asr==2.1.0) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-k2-asr==2.1.0) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-k2-asr==2.1.0) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-k2-asr==2.1.0) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-k2-asr==2.1.0) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-k2-asr==2.1.0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-k2-asr==2.1.0) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-k2-asr==2.1.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-k2-asr==2.1.0) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->reazonspeech-k2-asr==2.1.0) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->reazonspeech-k2-asr==2.1.0) (2.22)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa->reazonspeech-k2-asr==2.1.0) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa->reazonspeech-k2-asr==2.1.0) (4.3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->reazonspeech-k2-asr==2.1.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->reazonspeech-k2-asr==2.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->reazonspeech-k2-asr==2.1.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->reazonspeech-k2-asr==2.1.0) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa->reazonspeech-k2-asr==2.1.0) (3.5.0)
# Downloading sherpa_onnx-1.10.33-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 66.5 MB/s eta 0:00:00
# Building wheels for collected packages: reazonspeech-k2-asr
#   Building wheel for reazonspeech-k2-asr (pyproject.toml) ... done
#   Created wheel for reazonspeech-k2-asr: filename=reazonspeech_k2_asr-2.1.0-py3-none-any.whl size=4522 sha256=19e56c81e518aad2c2bb466da8e24a798c8412e1910effc8c1b189e2c7a5e09b
#   Stored in directory: /root/.cache/pip/wheels/15/90/3b/b4d6096eadf14219f73cc4b248eedcd664e28a46239258b1fe
# Successfully built reazonspeech-k2-asr
# Installing collected packages: sherpa-onnx, reazonspeech-k2-asr
# Successfully installed reazonspeech-k2-asr-2.1.0 sherpa-onnx-1.10.33
# Processing ./reazonspeech/pkg/espnet-asr
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo (from reazonspeech-espnet-asr==2.1.0)
#   Cloning https://github.com/espnet/espnet_model_zoo to /tmp/pip-install-kkfrwrxl/espnet-model-zoo_7363ce5cb7a349b8a819134d465e0a6a
#   Running command git clone --filter=blob:none --quiet https://github.com/espnet/espnet_model_zoo /tmp/pip-install-kkfrwrxl/espnet-model-zoo_7363ce5cb7a349b8a819134d465e0a6a
#   Resolved https://github.com/espnet/espnet_model_zoo to commit 8b7301923c1c529a126c86c16fc73ce356b94d62
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from reazonspeech-espnet-asr==2.1.0) (1.26.4)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from reazonspeech-espnet-asr==2.1.0) (0.10.2.post1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from reazonspeech-espnet-asr==2.1.0) (0.12.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from reazonspeech-espnet-asr==2.1.0) (2.5.1+cu121)
# Collecting ctc-segmentation (from reazonspeech-espnet-asr==2.1.0)
#   Downloading ctc_segmentation-1.7.4.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 2.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting espnet (from reazonspeech-espnet-asr==2.1.0)
#   Downloading espnet-202412-py3-none-any.whl.metadata (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.5/70.5 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from ctc-segmentation->reazonspeech-espnet-asr==2.1.0) (75.1.0)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from ctc-segmentation->reazonspeech-espnet-asr==2.1.0) (3.0.11)
# Collecting setuptools (from ctc-segmentation->reazonspeech-espnet-asr==2.1.0)
#   Downloading setuptools-73.0.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from espnet->reazonspeech-espnet-asr==2.1.0) (24.2)
# Collecting configargparse>=1.2.1 (from espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading ConfigArgParse-1.7-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.10/dist-packages (from espnet->reazonspeech-espnet-asr==2.1.0) (4.4.1)
# Collecting humanfriendly (from espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from espnet->reazonspeech-espnet-asr==2.1.0) (1.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from espnet->reazonspeech-espnet-asr==2.1.0) (3.16.1)
# Collecting librosa (from reazonspeech-espnet-asr==2.1.0)
#   Downloading librosa-0.9.2-py3-none-any.whl.metadata (8.2 kB)
# Collecting jamo==0.4.1 (from espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: PyYAML>=5.1.2 in /usr/local/lib/python3.10/dist-packages (from espnet->reazonspeech-espnet-asr==2.1.0) (6.0.2)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from espnet->reazonspeech-espnet-asr==2.1.0) (3.12.1)
# Requirement already satisfied: kaldiio>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from espnet->reazonspeech-espnet-asr==2.1.0) (2.18.0)
# Collecting torch-complex (from espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading torch_complex-0.4.4-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: nltk>=3.4.5 in /usr/local/lib/python3.10/dist-packages (from espnet->reazonspeech-espnet-asr==2.1.0) (3.9.1)
# Collecting numpy (from reazonspeech-espnet-asr==2.1.0)
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from espnet->reazonspeech-espnet-asr==2.1.0) (4.25.5)
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.10/dist-packages (from espnet->reazonspeech-espnet-asr==2.1.0) (1.3.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from espnet->reazonspeech-espnet-asr==2.1.0) (3.4.0)
# Collecting sentencepiece==0.1.97 (from espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading sentencepiece-0.1.97-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting pyworld>=0.3.4 (from espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading pyworld-0.3.4.tar.gz (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.0/252.0 kB 9.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pypinyin<=0.44.0 (from espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading pypinyin-0.44.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting espnet-tts-frontend (from espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading espnet_tts_frontend-0.0.3-py3-none-any.whl.metadata (3.4 kB)
# Collecting ci-sdr (from espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading ci_sdr-0.0.2.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fast-bss-eval==0.1.3 (from espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading fast_bss_eval-0.1.3.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Collecting asteroid-filterbanks==0.4.0 (from espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from espnet->reazonspeech-espnet-asr==2.1.0) (0.8.1)
# Collecting importlib-metadata<5.0 (from espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-espnet-asr==2.1.0) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-espnet-asr==2.1.0) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-espnet-asr==2.1.0) (1.4.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-espnet-asr==2.1.0) (4.4.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-espnet-asr==2.1.0) (0.4.3)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-espnet-asr==2.1.0) (0.60.0)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->reazonspeech-espnet-asr==2.1.0) (1.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from asteroid-filterbanks==0.4.0->espnet->reazonspeech-espnet-asr==2.1.0) (4.12.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->reazonspeech-espnet-asr==2.1.0) (1.17.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->reazonspeech-espnet-asr==2.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->reazonspeech-espnet-asr==2.1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->reazonspeech-espnet-asr==2.1.0) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->reazonspeech-espnet-asr==2.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->reazonspeech-espnet-asr==2.1.0) (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (4.66.6)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (0.26.3)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (2.5.1+cu121)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->reazonspeech-espnet-asr==2.1.0) (2.22)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<5.0->espnet->reazonspeech-espnet-asr==2.1.0) (3.21.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4.5->espnet->reazonspeech-espnet-asr==2.1.0) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4.5->espnet->reazonspeech-espnet-asr==2.1.0) (2024.9.11)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.45.1->librosa->reazonspeech-espnet-asr==2.1.0) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa->reazonspeech-espnet-asr==2.1.0) (4.3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->librosa->reazonspeech-espnet-asr==2.1.0) (3.5.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from ci-sdr->espnet->reazonspeech-espnet-asr==2.1.0) (0.8.0)
# Collecting unidecode>=1.0.22 (from espnet-tts-frontend->espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: inflect>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from espnet-tts-frontend->espnet->reazonspeech-espnet-asr==2.1.0) (7.4.0)
# Collecting jaconv (from espnet-tts-frontend->espnet->reazonspeech-espnet-asr==2.1.0)
#   Downloading jaconv-0.4.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: g2p-en in /usr/local/lib/python3.10/dist-packages (from espnet-tts-frontend->espnet->reazonspeech-espnet-asr==2.1.0) (2.1.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.10/dist-packages (from hydra-core->espnet->reazonspeech-espnet-asr==2.1.0) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core->espnet->reazonspeech-espnet-asr==2.1.0) (4.9.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->reazonspeech-espnet-asr==2.1.0) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (2024.2)
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.10/dist-packages (from inflect>=1.0.0->espnet-tts-frontend->espnet->reazonspeech-espnet-asr==2.1.0) (10.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->espnet_model_zoo@ git+https://github.com/espnet/espnet_model_zoo->reazonspeech-espnet-asr==2.1.0) (1.16.0)
# Requirement already satisfied: distance>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from g2p-en->espnet-tts-frontend->espnet->reazonspeech-espnet-asr==2.1.0) (0.1.3)
# Downloading espnet-202412-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 37.9 MB/s eta 0:00:00
# Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 13.6 MB/s eta 0:00:00
# Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl (29 kB)
# Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Downloading sentencepiece-0.1.97-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.6 MB/s eta 0:00:00
# Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 79.2 MB/s eta 0:00:00
# Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Downloading pypinyin-0.44.0-py2.py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.4 MB/s eta 0:00:00
# Downloading setuptools-73.0.1-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 60.3 MB/s eta 0:00:00
# Downloading espnet_tts_frontend-0.0.3-py3-none-any.whl (11 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.2 MB/s eta 0:00:00
# Downloading torch_complex-0.4.4-py3-none-any.whl (9.1 kB)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 14.2 MB/s eta 0:00:00
# Building wheels for collected packages: reazonspeech-espnet-asr, ctc-segmentation, fast-bss-eval, espnet_model_zoo, pyworld, ci-sdr, jaconv
#   Building wheel for reazonspeech-espnet-asr (pyproject.toml) ... done
#   Created wheel for reazonspeech-espnet-asr: filename=reazonspeech_espnet_asr-2.1.0-py3-none-any.whl size=7764 sha256=1f462d971c15535ea726c39e061f8a868e9ee60cddfd8cf75bf7dd57845466ae
#   Stored in directory: /root/.cache/pip/wheels/ad/bc/e2/e7f64f7a82b3aa4ca43c7cea3630b28c02784e9ccd87ad8f07
#   Building wheel for ctc-segmentation (pyproject.toml) ... done
#   Created wheel for ctc-segmentation: filename=ctc_segmentation-1.7.4-cp310-cp310-linux_x86_64.whl size=150904 sha256=58b8adb519ff27c669cb9ed0e45ee74eb8832b43b8c6a0ccd75d1ca2ca6a56d0
#   Stored in directory: /root/.cache/pip/wheels/63/8d/64/062be0990aac6687780c9f5998af6ba110daad94354a57cea0
#   Building wheel for fast-bss-eval (setup.py) ... done
#   Created wheel for fast-bss-eval: filename=fast_bss_eval-0.1.3-py3-none-any.whl size=44242 sha256=ed518cbc152aa2b985b048f49d622d4f09a70cfa409480a1b7808520d26cb7da
#   Stored in directory: /root/.cache/pip/wheels/d3/f4/f9/ee0192638b716fef471c69d5e5ae6e0c1f5d45dfcd53d6c3c1
#   Building wheel for espnet_model_zoo (setup.py) ... done
#   Created wheel for espnet_model_zoo: filename=espnet_model_zoo-0.1.8-py3-none-any.whl size=20489 sha256=70c83ed1e1ba682aaa965c3d6a0003a9e1ecebf56194758edaf66ee4de675741
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_gu4kwo4/wheels/71/8a/00/ff40006ac6bc83bca9c53a89191d8de4e7cebf94bd8780c3f0
#   Building wheel for pyworld (pyproject.toml) ... done
#   Created wheel for pyworld: filename=pyworld-0.3.4-cp310-cp310-linux_x86_64.whl size=862372 sha256=6e61302d346fb8c5115ed267bc77996c46f21f9fe0d5ea8fec8f6fe466bd8f5b
#   Stored in directory: /root/.cache/pip/wheels/66/09/8a/a1d79b73d59756f66e9bfe55a199840efc7473adb76ddacdfd
#   Building wheel for ci-sdr (setup.py) ... done
#   Created wheel for ci-sdr: filename=ci_sdr-0.0.2-py3-none-any.whl size=15252 sha256=64e51f00a83f26e3cc3f3346d5cfec16e146d53ecd2a58c2b4de40c3b84454aa
#   Stored in directory: /root/.cache/pip/wheels/09/e7/93/aeaa1689a57e615b04248758ae7f9af5a71a8b0b5b2dd397c8
#   Building wheel for jaconv (setup.py) ... done
#   Created wheel for jaconv: filename=jaconv-0.4.0-py3-none-any.whl size=18229 sha256=24472dea20cb3f228aca8712fc9885dae10971d712d47e950fdabd5cbc613522
#   Stored in directory: /root/.cache/pip/wheels/20/95/99/94e8d7545125181756857f6b1fc085ed4e0811ad9be7321af7
# Successfully built reazonspeech-espnet-asr ctc-segmentation fast-bss-eval espnet_model_zoo pyworld ci-sdr jaconv
# Installing collected packages: sentencepiece, jamo, jaconv, unidecode, setuptools, pypinyin, numpy, importlib-metadata, humanfriendly, configargparse, torch-complex, pyworld, ctc-segmentation, fast-bss-eval, ci-sdr, asteroid-filterbanks, librosa, espnet-tts-frontend, espnet, espnet_model_zoo, reazonspeech-espnet-asr
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.2.0
#     Uninstalling sentencepiece-0.2.0:
#       Successfully uninstalled sentencepiece-0.2.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.5.0
#     Uninstalling importlib_metadata-8.5.0:
#       Successfully uninstalled importlib_metadata-8.5.0
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.2.post1
#     Uninstalling librosa-0.10.2.post1:
#       Successfully uninstalled librosa-0.10.2.post1
# Successfully installed asteroid-filterbanks-0.4.0 ci-sdr-0.0.2 configargparse-1.7 ctc-segmentation-1.7.4 espnet-202412 espnet-tts-frontend-0.0.3 espnet_model_zoo-0.1.8 fast-bss-eval-0.1.3 humanfriendly-10.0 importlib-metadata-4.13.0 jaconv-0.4.0 jamo-0.4.1 librosa-0.9.2 numpy-1.23.5 pypinyin-0.44.0 pyworld-0.3.4 reazonspeech-espnet-asr-2.1.0 sentencepiece-0.1.97 setuptools-73.0.1 torch-complex-0.4.4 unidecode-1.3.8

# %%
# !pip install jiwer
# !apt-get install -y mecab libmecab-dev mecab-ipadic-utf8
# !pip install mecab-python3
# Out:
# Requirement already satisfied: jiwer in /usr/local/lib/python3.10/dist-packages (3.0.5)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Requirement already satisfied: rapidfuzz<4,>=3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (3.10.1)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libmecab2 mecab-ipadic mecab-utils
# The following NEW packages will be installed:
#   libmecab-dev libmecab2 mecab mecab-ipadic mecab-ipadic-utf8 mecab-utils
# 0 upgraded, 6 newly installed, 0 to remove and 49 not upgraded.
# Need to get 7,367 kB of archives.
# After this operation, 59.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmecab2 amd64 0.996-14build9 [199 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmecab-dev amd64 0.996-14build9 [306 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 mecab-utils amd64 0.996-14build9 [4,850 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 mecab-ipadic all 2.7.0-20070801+main-3 [6,718 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 mecab amd64 0.996-14build9 [136 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 mecab-ipadic-utf8 all 2.7.0-20070801+main-3 [4,384 B]
# Fetched 7,367 kB in 1s (5,806 kB/s)
# Selecting previously unselected package libmecab2:amd64.
# (Reading database ... 123632 files and directories currently installed.)
# Preparing to unpack .../0-libmecab2_0.996-14build9_amd64.deb ...
# Unpacking libmecab2:amd64 (0.996-14build9) ...
# Selecting previously unselected package libmecab-dev.
# Preparing to unpack .../1-libmecab-dev_0.996-14build9_amd64.deb ...
# Unpacking libmecab-dev (0.996-14build9) ...
# Selecting previously unselected package mecab-utils.
# Preparing to unpack .../2-mecab-utils_0.996-14build9_amd64.deb ...
# Unpacking mecab-utils (0.996-14build9) ...
# Selecting previously unselected package mecab-ipadic.
# Preparing to unpack .../3-mecab-ipadic_2.7.0-20070801+main-3_all.deb ...
# Unpacking mecab-ipadic (2.7.0-20070801+main-3) ...
# Selecting previously unselected package mecab.
# Preparing to unpack .../4-mecab_0.996-14build9_amd64.deb ...
# Unpacking mecab (0.996-14build9) ...
# Selecting previously unselected package mecab-ipadic-utf8.
# Preparing to unpack .../5-mecab-ipadic-utf8_2.7.0-20070801+main-3_all.deb ...
# Unpacking mecab-ipadic-utf8 (2.7.0-20070801+main-3) ...
# Setting up libmecab2:amd64 (0.996-14build9) ...
# Setting up libmecab-dev (0.996-14build9) ...
# Setting up mecab-utils (0.996-14build9) ...
# Setting up mecab-ipadic (2.7.0-20070801+main-3) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27328
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up mecab (0.996-14build9) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27328
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-ipadic-utf8 (2.7.0-20070801+main-3) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27328
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic-utf8 to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# Collecting mecab-python3
#   Downloading mecab_python3-1.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Downloading mecab_python3-1.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (581 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.7/581.7 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: mecab-python3
# Successfully installed mecab-python3-1.0.10

# %%
import os

# Directory structure for the audio files:
# - The "basic5000" folder contains the dataset for testing.
# - Inside "basic5000":
#     - A subfolder named "wav" stores multiple audio files (*.wav).
#     - A text file named "transcript_utf8.txt" serves as the ground truth transcription file
#       and contains the corresponding text for the audio files in UTF-8 encoding.
#
# This structure is identical to the "basic5000" folder inside the "jsut_ver1.1" dataset,
# which can be downloaded from the following URL:
# https://sites.google.com/site/shinnosuketakamichi/publication/jsut
#
# The organization ensures compatibility with the JSUT corpus for ASR tasks.


base_dir = "basic5000"
wav_dir = os.path.join(base_dir, "wav")
os.makedirs(wav_dir, exist_ok=True)

# Please manually upload wav files and transcript_utf8.txt from basic5000.

# %%
from reazonspeech.nemo.asr import transcribe as nemo_transcribe, audio_from_path as nemo_audio_from_path, load_model as load_reazon_nemo
from reazonspeech.k2.asr import transcribe as k2_transcribe, audio_from_path as k2_audio_from_path, load_model as load_reazon_k2
from reazonspeech.espnet.asr import transcribe as espnet_transcribe, audio_from_path as espnet_audio_from_path, load_model as load_reazon_espnet
from jiwer import cer, wer
import os
import re
import MeCab
import pandas as pd
from google.colab import files
import whisper
import torchaudio

# Paths
audio_folder_path = "basic5000/wav"
transcript_file_path = "basic5000/transcript_utf8.txt"

# Initialize MeCab
mecab = MeCab.Tagger("-Owakati -r /etc/mecabrc")  # Use wakati mode to tokenize into words

# Normalize text by converting full-width characters to half-width and removing punctuation/spaces
def normalize(text):
    """
    Normalize text by:
    1. Converting full-width characters to half-width.
    2. Removing Japanese punctuation marks (、。) and spaces.
    """
    FULLWIDTH_TO_HALFWIDTH = str.maketrans(
        "　０１２３４５６７８９ａｂｃｄｅｆｇｈｉｊｋｌｍｎｏｐｑｒｓｔｕｖｗｘｙｚＡＢＣＤＥＦＧＨＩＪＫＬＭＮＯＰＱＲＳＴＵＶＷＸＹＺ！゛＃＄％＆（）＊＋ー／：；〈＝〉？＠［］＾＿'｛｜｝～",
        ' 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&()*+-/:;<=>?@[]^_`{|}~'
    )
    # Convert full-width to half-width
    text = text.translate(FULLWIDTH_TO_HALFWIDTH)
    # Remove punctuation and spaces
    text = re.sub(r"[、。 ]", "", text)
    return text

# Function to tokenize text using MeCab
def tokenize_text(text):
    return mecab.parse(text).strip()  # Tokenize and remove trailing newline

# Load ground truth transcripts into a dictionary
def load_transcripts(transcript_file_path):
    transcripts = {}
    with open(transcript_file_path, "r", encoding="utf-8") as f:
        for line in f:
            key, text = line.strip().split(":", 1)
            transcripts[key] = text.strip()
    return transcripts

# Transcribe audio using Whisper
def transcribe_whisper(model, audio_path):
    result = model.transcribe(audio_path, fp16=True)
    return result['text'].strip()

# Transcribe audio using ReazonSpeech Nemo
def transcribe_reazon_nemo(model, audio_path):
    audio = nemo_audio_from_path(audio_path)
    result = nemo_transcribe(model, audio)
    return " ".join([seg.text for seg in result.segments])

# Transcribe audio using ReazonSpeech K2
def transcribe_reazon_k2(model, audio_path):
    audio = k2_audio_from_path(audio_path)
    result = k2_transcribe(model, audio)
    return result.text

# Transcribe audio using ReazonSpeech ESPnet
def transcribe_reazon_espnet(model, audio_path):
    audio = espnet_audio_from_path(audio_path)
    result = espnet_transcribe(model, audio)
    return result.text

# Function to load models based on type
def load_model(model_name):
    if model_name.startswith("whisper_"):
        return whisper.load_model(model_name.split("_")[1])
    elif model_name == "reazonspeech_nemo":
        return load_reazon_nemo()
    elif model_name == "reazonspeech_k2":
        return load_reazon_k2()
    elif model_name == "reazonspeech_espnet":
        return load_reazon_espnet()
    else:
        raise ValueError(f"Unsupported model: {model_name}")

# Evaluate CER and WER for a single model
def evaluate_model(model_name, audio_folder_path, transcript_file_path, max_files_to_process=10, do_normalize=True):
    """
    Evaluate CER and WER for a given model.

    Args:
        model_name (str): The name of the ASR model to evaluate.
        audio_folder_path (str): Path to the folder containing audio files.
        transcript_file_path (str): Path to the transcript file.
        max_files_to_process (int): Maximum number of files to process, allowing evaluation on a limited number of files instead of all available files.
        normalize (boolean): If True, normalize text by converting full-width to half-width and removing punctuation.
    """
    transcripts = load_transcripts(transcript_file_path)
    results = []

    print(f"Evaluating model: {model_name}")
    model = load_model(model_name)
    total_cer = 0.0
    total_wer = 0.0
    count = 0

    for idx, filename in enumerate(os.listdir(audio_folder_path)):
        if filename.endswith(".wav") and idx < max_files_to_process:
            audio_id = os.path.splitext(filename)[0]
            audio_path = os.path.join(audio_folder_path, filename)

            if audio_id in transcripts:
                ground_truth = transcripts[audio_id]
                try:
                    if model_name.startswith("whisper_"):
                        recognized_text = transcribe_whisper(model, audio_path)
                    elif model_name == "reazonspeech_nemo":
                        recognized_text = transcribe_reazon_nemo(model, audio_path)
                    elif model_name == "reazonspeech_k2":
                        recognized_text = transcribe_reazon_k2(model, audio_path)
                    elif model_name == "reazonspeech_espnet":
                        recognized_text = transcribe_reazon_espnet(model, audio_path)
                    else:
                        continue

                    if do_normalize:
                        ground_truth = normalize(ground_truth)
                        recognized_text = normalize(recognized_text)

                    ground_truth_tokenized = tokenize_text(ground_truth)
                    recognized_text_tokenized = tokenize_text(recognized_text)

                    cer_score = cer(ground_truth, recognized_text)
                    wer_score = wer(ground_truth_tokenized, recognized_text_tokenized)

                    total_cer += cer_score
                    total_wer += wer_score
                    count += 1

                    results.append({
                        "Model": model_name,
                        "Audio ID": audio_id,
                        "CER": cer_score,
                        "WER": wer_score,
                        "Ground Truth": ground_truth,
                        "Recognized Text": recognized_text
                    })
                except Exception as e:
                    print(f"Error processing {audio_id} with {model_name}: {e}")

    average_cer = total_cer / count if count > 0 else 0
    average_wer = total_wer / count if count > 0 else 0
    print("\n", end="")
    print(f"Average CER for {model_name}: {average_cer:.2%}")
    print(f"Average WER for {model_name}: {average_wer:.2%}")
    print("\n", end="")

    # Save results to CSV and download immediately
    df = pd.DataFrame(results)
    csv_filename = f"{model_name}_evaluation_results.csv"
    df.to_csv(csv_filename, index=False)
    # files.download(csv_filename)

# Define models
whisper_models = ["whisper_tiny", "whisper_base", "whisper_small", "whisper_medium", "whisper_large"]
reazonspeech_models = ["reazonspeech_nemo", "reazonspeech_k2", "reazonspeech_espnet"]

# %%
# Evaluate Whisper models
print("Evaluating Whisper models...")
for model in whisper_models:
    evaluate_model(model, audio_folder_path, transcript_file_path, max_files_to_process=10, do_normalize=True)
# Out:
# Evaluating Whisper models...
# Evaluating model: whisper_tiny
# 100%|█████████████████████████████████████| 72.1M/72.1M [00:01<00:00, 45.1MiB/s]
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Average CER for whisper_tiny: 44.97%
# Average WER for whisper_tiny: 53.64%
# Evaluating model: whisper_base
# 100%|███████████████████████████████████████| 139M/139M [00:02<00:00, 58.6MiB/s]
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Average CER for whisper_base: 27.66%
# Average WER for whisper_base: 34.75%
# Evaluating model: whisper_small
# 100%|████████████████████████████████████████| 461M/461M [00:04<00:00, 111MiB/s]
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Average CER for whisper_small: 14.76%
# Average WER for whisper_small: 18.51%
# Evaluating model: whisper_medium
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:26<00:00, 56.8MiB/s]
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Average CER for whisper_medium: 12.20%
# Average WER for whisper_medium: 14.63%
# Evaluating model: whisper_large
# 100%|█████████████████████████████████████| 2.88G/2.88G [00:47<00:00, 64.6MiB/s]
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Average CER for whisper_large: 6.14%
# Average WER for whisper_large: 6.46%

# %%
# Evaluate ReazonSpeech models
print("Evaluating ReazonSpeech models...")
for model in reazonspeech_models:
    evaluate_model(model, audio_folder_path, transcript_file_path, max_files_to_process=10, do_normalize=True)
# Out:
# Evaluating ReazonSpeech models...
# Evaluating model: reazonspeech_nemo
# reazonspeech-nemo-v2.nemo:   0%|          | 0.00/2.48G [00:00<?, ?B/s]
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s][NeMo W 2024-12-06 14:31:02 deprecated:65] Function ``_transcribe_output_processing`` is deprecated. The return type of args will be updated in the upcoming release to ensure a consistent output format across all decoder types, such that a "Hypothesis" object is always returned.
#
# Beam search progress::   0%|          | 0/1 [00:00<?, ?sample/s]
# Beam search progress:: 100%|██████████| 1/1 [00:02<00:00,  2.86s/sample]
# Transcribing: 100%|██████████| 1/1 [00:07<00:00,  7.88s/it]
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# Beam search progress::   0%|          | 0/1 [00:00<?, ?sample/s]
# Beam search progress:: 100%|██████████| 1/1 [00:01<00:00,  1.25s/sample]
# Transcribing: 100%|██████████| 1/1 [00:05<00:00,  5.29s/it]
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# Beam search progress::   0%|          | 0/1 [00:00<?, ?sample/s]
# Beam search progress:: 100%|██████████| 1/1 [00:00<00:00,  1.15sample/s]
# Transcribing: 100%|██████████| 1/1 [00:03<00:00,  3.91s/it]
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# Beam search progress::   0%|          | 0/1 [00:00<?, ?sample/s]
# Beam search progress:: 100%|██████████| 1/1 [00:00<00:00,  1.85sample/s]
# Transcribing: 100%|██████████| 1/1 [00:04<00:00,  4.12s/it]
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# Beam search progress::   0%|          | 0/1 [00:00<?, ?sample/s]
# Beam search progress:: 100%|██████████| 1/1 [00:00<00:00,  1.75sample/s]
# Transcribing: 100%|██████████| 1/1 [00:04<00:00,  4.08s/it]
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# Beam search progress::   0%|          | 0/1 [00:00<?, ?sample/s]
# Beam search progress:: 100%|██████████| 1/1 [00:01<00:00,  1.05s/sample]
# Transcribing: 100%|██████████| 1/1 [00:03<00:00,  3.56s/it]
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# Beam search progress::   0%|          | 0/1 [00:00<?, ?sample/s]
# Beam search progress:: 100%|██████████| 1/1 [00:00<00:00,  1.43sample/s]
# Transcribing: 100%|██████████| 1/1 [00:03<00:00,  3.47s/it]
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# Beam search progress::   0%|          | 0/1 [00:00<?, ?sample/s]
# Beam search progress:: 100%|██████████| 1/1 [00:01<00:00,  1.92s/sample]
# Transcribing: 100%|██████████| 1/1 [00:06<00:00,  6.34s/it]
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# Beam search progress::   0%|          | 0/1 [00:00<?, ?sample/s]
# Beam search progress:: 100%|██████████| 1/1 [00:01<00:00,  1.14s/sample]
# Transcribing: 100%|██████████| 1/1 [00:03<00:00,  3.85s/it]
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# Beam search progress::   0%|          | 0/1 [00:00<?, ?sample/s]
# Beam search progress:: 100%|██████████| 1/1 [00:01<00:00,  1.10s/sample]
# Transcribing: 100%|██████████| 1/1 [00:03<00:00,  3.89s/it]
# Average CER for reazonspeech_nemo: 5.36%
# Average WER for reazonspeech_nemo: 5.67%
# Evaluating model: reazonspeech_k2
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# joiner-epoch-99-avg-1.int8.onnx:   0%|          | 0.00/2.70M [00:00<?, ?B/s]
# decoder-epoch-99-avg-1.int8.onnx:   0%|          | 0.00/2.96M [00:00<?, ?B/s]
# encoder-epoch-99-avg-1.int8.onnx:   0%|          | 0.00/155M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# decoder-epoch-99-avg-1.onnx:   0%|          | 0.00/11.8M [00:00<?, ?B/s]
# joiner-epoch-99-avg-1.onnx:   0%|          | 0.00/10.7M [00:00<?, ?B/s]
# encoder-epoch-99-avg-1.onnx:   0%|          | 0.00/592M [00:00<?, ?B/s]
# tokens.txt:   0%|          | 0.00/45.8k [00:00<?, ?B/s]
# Average CER for reazonspeech_k2: 4.46%
# Average WER for reazonspeech_k2: 5.54%
# Evaluating model: reazonspeech_espnet
# Failed to import Flash Attention, using ESPnet default: No module named 'flash_attn'
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# (…)in_asr_conformer_raw_jp_char/config.yaml:   0%|          | 0.00/35.3k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# feats_stats.npz:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# meta.yaml:   0%|          | 0.00/400 [00:00<?, ?B/s]
# exp/lm_train_lm_jp_char/config.yaml:   0%|          | 0.00/33.5k [00:00<?, ?B/s]
# 40epoch.pth:   0%|          | 0.00/347M [00:00<?, ?B/s]
# valid.acc.ave_10best.pth:   0%|          | 0.00/476M [00:00<?, ?B/s]
# Transcribe: 100%|██████████| 122400/122400 [00:36<00:00, 3369.25it/s]
# Transcribe: 100%|██████████| 136640/136640 [00:41<00:00, 3264.45it/s]
# Transcribe: 100%|██████████| 80800/80800 [00:18<00:00, 4351.37it/s]
# Transcribe: 100%|██████████| 44960/44960 [00:08<00:00, 5338.22it/s]
# Transcribe: 100%|██████████| 59040/59040 [00:11<00:00, 4972.81it/s]
# Transcribe: 100%|██████████| 50400/50400 [00:09<00:00, 5551.67it/s]
# Transcribe: 100%|██████████| 64160/64160 [00:14<00:00, 4438.16it/s]
# Transcribe: 100%|██████████| 78560/78560 [00:15<00:00, 5079.39it/s]
# Transcribe: 100%|██████████| 56640/56640 [00:10<00:00, 5449.12it/s]
# Transcribe: 100%|██████████| 58240/58240 [00:11<00:00, 4878.19it/s]
# Average CER for reazonspeech_espnet: 4.81%
# Average WER for reazonspeech_espnet: 4.91%
